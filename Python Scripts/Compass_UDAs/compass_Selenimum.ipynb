# %% [markdown]
# # Code for activity

# %%
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
import re
from bs4 import BeautifulSoup
import os
import requests
from selenium.webdriver.chrome.options import Options
import pdfplumber
import pyautogui

import urllib.request


# Path to ChromeDriver executable
chrome_driver_path = "C:\\Users\\Awan\\Downloads\\chromedriver-win64\\chromedriver.exe"  # Adjust this path accordingly


# URL of the login page
url = "https://compass.nhsbsa.nhs.uk/auth/esr.elogin"

# Create a Selenium WebDriver instance
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the login page
driver.get(url)

# Wait for the page to load
time.sleep(2)

memorable_word_text= "sfDceyhj3eLd"

# Find the Memorable word character inputs
memorable_word_positions = []
memorable_word_inputs = driver.find_elements(By.CLASS_NAME, "memorable_word")
for input_element in memorable_word_inputs:
    # Extract the position using regular expressions
    aria_label = input_element.get_attribute("aria-label")
    position_match = re.search(r"Enter (\d+)st|(\d+)nd|(\d+)rd|(\d+)th character", aria_label)
    if position_match:
        position = int(next(filter(None, position_match.groups())))
        memorable_word_positions.append(position)
print(memorable_word_positions)

# Find username, password, and memorable word fields and fill them
driver.find_element(By.ID, "logon.username").send_keys("rghauri")
driver.find_element(By.ID, "logon.password").send_keys("sdrF35^&$sH")
driver.find_element(By.ID, "memorable_word_one").send_keys(memorable_word_text[memorable_word_positions[0]-1])
driver.find_element(By.ID, "memorable_word_two").send_keys(memorable_word_text[memorable_word_positions[1]-1])
driver.find_element(By.ID, "memorable_word_three").send_keys(memorable_word_text[memorable_word_positions[2]-1])

# Submit the form
driver.find_element(By.CLASS_NAME, "go_button").click()

# Wait for the login process to complete
time.sleep(5)

# Click on the "Activity" element
activity_element = driver.find_element(By.XPATH, "//div[@name='menu_option_9']")
activity_element.click()

# Wait for the "Activity" page to load
time.sleep(2)
# Click on the "activity_search" link
activity_search_element = driver.find_element(By.XPATH, "//div[@name='menu_option_13']")
activity_search_element.click()

# Wait for the "activity_search" page to load
time.sleep(2)

contract_ids = [
    #"1001710000",
    #"1016580000",
    #"1016590000",issue
    "3954630001",
    "3954630002",
    "3954630004",
    "3954630006",
    "3954630007",
    "3954630008",
    #"3954630009",issue
]

for contract_id in contract_ids:
    # Add number into Contract ID field
    contract_id_field = driver.find_element(By.ID, "contract_id")
    contract_id_field.clear()
    contract_id_field.send_keys(contract_id)



    time.sleep(2)
# enter date starting
    from_date_field = driver.find_element(By.ID, "from_date")
    from_date_field.clear()
    from_date_field.click();
    from_date_field.send_keys("01/04/2024 13:14")
# enter date end
    to_date_field = driver.find_element(By.ID, "to_date")
    to_date_field.clear()
    to_date_field.click();
    to_date_field.send_keys("30/04/2024 13:14")

# Click on the "Search" button
    search_button = driver.find_element(By.ID, "search")
    search_button.click()

    time.sleep(10)



# Wait for the button element to be present in the DOM and visible on the page
    driver.find_element(By.CLASS_NAME, "esr_grid_context_buttons").click()



# Wait for the search results to load
    time.sleep(2)

    ok_button = driver.find_element(By.ID, "control_span_esr_ok")
    ok_button.click()

    time.sleep(20)
if "Welcome" in driver.page_source:
    print("Login successful!")
else:
    print("Login failed.")

# Close the browser
#driver.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5944/1421018312.py in <module>
#      25 # Create a Selenium WebDriver instance
#      26 service = Service(chrome_driver_path)
# ---> 27 driver = webdriver.Chrome(service=service)
#      28
#      29 # Navigate to the login page
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      59
#      60         try:
# ---> 61             super().__init__(command_executor=executor, options=options)
#      62         except Exception:
#      63             self.quit()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, keep_alive, file_detector, options)
#     206         self._authenticator_id = None
#     207         self.start_client()
# --> 208         self.start_session(capabilities)
#     209
#     210     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities)
#     290
#     291         caps = _create_caps(capabilities)
# --> 292         response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293         self.session_id = response.get("sessionId")
#     294         self.caps = response.get("capabilities")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response["value"] = self._unwrap_value(response.get("value", None))
#     349             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 124
# Current browser version is 126.0.6478.127 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# 	GetHandleVerifier [0x00007FF63193F922+3045234]
# 	(No symbol) [0x00007FF6315E3652]
# 	(No symbol) [0x00007FF6314A7564]
# 	(No symbol) [0x00007FF6314E4A92]
# 	(No symbol) [0x00007FF6314E3C92]
# 	(No symbol) [0x00007FF6314DDB7B]
# 	(No symbol) [0x00007FF6314D9C34]
# 	(No symbol) [0x00007FF631525219]
# 	(No symbol) [0x00007FF6315248E0]
# 	(No symbol) [0x00007FF631519B53]
# 	(No symbol) [0x00007FF6314E813C]
# 	(No symbol) [0x00007FF6314E8D71]
# 	GetHandleVerifier [0x00007FF63196E89D+3237613]
# 	GetHandleVerifier [0x00007FF6319B0BA7+3508727]
# 	GetHandleVerifier [0x00007FF6319A976F+3478975]
# 	GetHandleVerifier [0x00007FF63171F1C6+815126]
# 	(No symbol) [0x00007FF6315EED0F]
# 	(No symbol) [0x00007FF6315E9854]
# 	(No symbol) [0x00007FF6315E99E2]
# 	(No symbol) [0x00007FF6315DA574]
# 	BaseThreadInitThunk [0x00007FFBCC1A7374+20]
# 	RtlUserThreadStart [0x00007FFBCD8FCC91+33]

# %%
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
import re
from bs4 import BeautifulSoup
import os
import requests
from selenium.webdriver.chrome.options import Options
import pdfplumber
import pyautogui

import urllib.request

# Path to ChromeDriver executable
chrome_driver_path = "C:\\Users\\Awan\\Downloads\\chromedriver-win64\\chromedriver.exe"  # Adjust this path accordingly

# URL of the login page
url = "https://compass.nhsbsa.nhs.uk/auth/esr.elogin"

# Create a Selenium WebDriver instance
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)

# Navigate to the login page
driver.get(url)

# Wait for the page to load
time.sleep(30)

memorable_word_text = "sfDceyhj3eLd"

# Find the Memorable word character inputs
memorable_word_positions = []
memorable_word_inputs = driver.find_elements(By.CLASS_NAME, "memorable_word")
for input_element in memorable_word_inputs:
    # Extract the position using regular expressions
    aria_label = input_element.get_attribute("aria-label")
    position_match = re.search(r"Enter (\d+)st|(\d+)nd|(\d+)rd|(\d+)th character", aria_label)
    if position_match:
        position = int(next(filter(None, position_match.groups())))
        memorable_word_positions.append(position)
print(memorable_word_positions)

# Find username, password, and memorable word fields and fill them
driver.find_element(By.ID, "logon.username").send_keys("rghauri")
driver.find_element(By.ID, "logon.password").send_keys("sdrF35^&$sH")
driver.find_element(By.ID, "memorable_word_one").send_keys(memorable_word_text[memorable_word_positions[0]-1])
driver.find_element(By.ID, "memorable_word_two").send_keys(memorable_word_text[memorable_word_positions[1]-1])
driver.find_element(By.ID, "memorable_word_three").send_keys(memorable_word_text[memorable_word_positions[2]-1])

# Submit the form
driver.find_element(By.CLASS_NAME, "go_button").click()

# Wait for the login process to complete
time.sleep(30)

# Click on the "Contract" element
contract_element = driver.find_element(By.XPATH, "//div[@name='menu_option_4']")
contract_element.click()
time.sleep(2)

# Find the contract ID input field and insert the contract ID
contract_id_field = driver.find_element(By.ID, "sid3344_main_CONTRACTS_GRID")
contract_id_field.clear()
contract_id_field.click()
contract_id_field.send_keys("3954630002")

# Wait for the search results to load
time.sleep(2)

# Add any additional steps if needed

# Close the browser
driver.quit()
# Out:
# [3, 6, 7]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5944/4188747505.py in <module>
#      64
#      65 # Find the contract ID input field and insert the contract ID
# ---> 66 contract_id_field = driver.find_element(By.ID, "sid3344_main_CONTRACTS_GRID")
#      67 contract_id_field.clear()
#      68 contract_id_field.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     739             value = f'[name="{value}"]'
#     740
# --> 741         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     742
#     743     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response["value"] = self._unwrap_value(response.get("value", None))
#     349             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="sid3344_main_CONTRACTS_GRID"]"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF63EDFEEA2+31554]
# 	(No symbol) [0x00007FF63ED77ED9]
# 	(No symbol) [0x00007FF63EC3872A]
# 	(No symbol) [0x00007FF63EC88434]
# 	(No symbol) [0x00007FF63EC8853C]
# 	(No symbol) [0x00007FF63ECCF6A7]
# 	(No symbol) [0x00007FF63ECAD06F]
# 	(No symbol) [0x00007FF63ECCC977]
# 	(No symbol) [0x00007FF63ECACDD3]
# 	(No symbol) [0x00007FF63EC7A33B]
# 	(No symbol) [0x00007FF63EC7AED1]
# 	GetHandleVerifier [0x00007FF63F108B1D+3217341]
# 	GetHandleVerifier [0x00007FF63F155AE3+3532675]
# 	GetHandleVerifier [0x00007FF63F14B0E0+3489152]
# 	GetHandleVerifier [0x00007FF63EEAE776+750614]
# 	(No symbol) [0x00007FF63ED8375F]
# 	(No symbol) [0x00007FF63ED7EB14]
# 	(No symbol) [0x00007FF63ED7ECA2]
# 	(No symbol) [0x00007FF63ED6E16F]
# 	BaseThreadInitThunk [0x00007FFBCC1A7374+20]
# 	RtlUserThreadStart [0x00007FFBCD8FCC91+33]
