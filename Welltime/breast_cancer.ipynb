# %%
import random
import pandas
import time
from random_forest import trainTestSplit, createRandomForest, randomForestPredictions, calculateAccuracy

dataFrame = pandas.read_csv("dataset_files/breast_cancer.csv")
dataFrame = dataFrame.drop("id", axis=1)
dataFrame = dataFrame[dataFrame.columns.tolist()[1:] +
                      dataFrame.columns.tolist()[0: 1]]
dataFrameTrain, dataFrameTest = trainTestSplit(dataFrame, testSize=0.25)

print("Random Forest - Breast Cancer Dataset")
print("  Maximum bootstrap size (n) is {}".format(dataFrameTrain.shape[0]))
print("  Maximum random subspace size (d) is {}".format(
    dataFrameTrain.shape[1] - 1))

print("\n  Change n, keep other parameters")

for i in range(10, dataFrameTrain.shape[0] + 1, 50):
    startTime = time.time()
    randomForest = createRandomForest(
        dataFrameTrain, bootstrapSize=i, randomAttributes=10, randomSplits=50, forestSize=30, treeMaxDepth=3)
    buildingTime = time.time() - startTime
    randomForestTestResults = randomForestPredictions(
        dataFrameTest, randomForest)
    accuracyTest = calculateAccuracy(
        randomForestTestResults, dataFrameTest.iloc[:, -1]) * 100
    randomForestTrainResults = randomForestPredictions(
        dataFrameTrain, randomForest)
    accuracyTrain = calculateAccuracy(
        randomForestTrainResults, dataFrameTrain.iloc[:, -1]) * 100
    print("  n = {}, d = {}, s = {}, k = {}, maxDepth = {}:".format(i, 10, 50, 30, 3))
    print("    accTest = {0:.2f}%, ".format(accuracyTest), end="")
    print("accTrain = {0:.2f}%, ".format(accuracyTrain), end="")
    print("buildTime = {0:.2f}s".format(buildingTime), end="\n")

print("\n  Change d, keep other parameters")

for i in range(10, dataFrameTrain.shape[1], 2):
    startTime = time.time()
    randomForest = createRandomForest(dataFrameTrain, bootstrapSize=60,
                                      randomAttributes=i, randomSplits=50, forestSize=30, treeMaxDepth=3)
    buildingTime = time.time() - startTime
    randomForestTestResults = randomForestPredictions(
        dataFrameTest, randomForest)
    accuracyTest = calculateAccuracy(
        randomForestTestResults, dataFrameTest.iloc[:, -1]) * 100
    randomForestTrainResults = randomForestPredictions(
        dataFrameTrain, randomForest)
    accuracyTrain = calculateAccuracy(
        randomForestTrainResults, dataFrameTrain.iloc[:, -1]) * 100
    print("  n = {}, d = {}, s = {}, k = {}, maxDepth = {}:".format(60, i, 50, 30, 3))
    print("    accTest = {0:.2f}%, ".format(accuracyTest), end="")
    print("accTrain = {0:.2f}%, ".format(accuracyTrain), end="")
    print("buildTime = {0:.2f}s".format(buildingTime), end="\n")

print("\n  Change s, keep other parameters")
for i in range(10, 100 + 1, 10):
    startTime = time.time()
    randomForest = createRandomForest(dataFrameTrain, bootstrapSize=60,
                                      randomAttributes=10, randomSplits=i, forestSize=30, treeMaxDepth=3)
    buildingTime = time.time() - startTime
    randomForestTestResults = randomForestPredictions(
        dataFrameTest, randomForest)
    accuracyTest = calculateAccuracy(
        randomForestTestResults, dataFrameTest.iloc[:, -1]) * 100
    randomForestTrainResults = randomForestPredictions(
        dataFrameTrain, randomForest)
    accuracyTrain = calculateAccuracy(
        randomForestTrainResults, dataFrameTrain.iloc[:, -1]) * 100
    print("  n = {}, d = {}, s = {}, k = {}, maxDepth = {}:".format(60, 10, i, 30, 3))
    print("    accTest = {0:.2f}%, ".format(accuracyTest), end="")
    print("accTrain = {0:.2f}%, ".format(accuracyTrain), end="")
    print("buildTime = {0:.2f}s".format(buildingTime), end="\n")

print("\n  Change k, keep other parameters")
for i in range(10, 100 + 1, 10):
    startTime = time.time()
    randomForest = createRandomForest(dataFrameTrain, bootstrapSize=60,
                                      randomAttributes=10, randomSplits=50, forestSize=i, treeMaxDepth=3)
    buildingTime = time.time() - startTime
    randomForestTestResults = randomForestPredictions(
        dataFrameTest, randomForest)
    accuracyTest = calculateAccuracy(
        randomForestTestResults, dataFrameTest.iloc[:, -1]) * 100
    randomForestTrainResults = randomForestPredictions(
        dataFrameTrain, randomForest)
    accuracyTrain = calculateAccuracy(
        randomForestTrainResults, dataFrameTrain.iloc[:, -1]) * 100
    print("  n = {}, d = {}, s = {}, k = {}, maxDepth = {}:".format(60, 10, 50, i, 3))
    print("    accTest = {0:.2f}%, ".format(accuracyTest), end="")
    print("accTrain = {0:.2f}%, ".format(accuracyTrain), end="")
    print("buildTime = {0:.2f}s".format(buildingTime), end="\n")
# Out:
# Random Forest - Breast Cancer Dataset
#   Maximum bootstrap size (n) is 427
#   Maximum random subspace size (d) is 30
#
#   Change n, keep other parameters
#   n = 10, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 92.04%, buildTime = 0.14s
#   n = 60, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 95.32%, buildTime = 0.43s
#   n = 110, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.25%, buildTime = 0.71s
#   n = 160, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 97.42%, buildTime = 0.81s
#   n = 210, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 97.42%, buildTime = 1.01s
#   n = 260, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 97.89%, buildTime = 1.09s
#   n = 310, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 96.48%, accTrain = 97.89%, buildTime = 1.39s
#   n = 360, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 92.96%, accTrain = 96.72%, buildTime = 1.37s
#   n = 410, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 97.89%, buildTime = 1.50s
#
#   Change d, keep other parameters
#   n = 60, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 95.55%, buildTime = 0.61s
#   n = 60, d = 12, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.77%, accTrain = 96.49%, buildTime = 0.47s
#   n = 60, d = 14, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 97.19%, buildTime = 0.52s
#   n = 60, d = 16, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 95.32%, buildTime = 0.48s
#   n = 60, d = 18, s = 50, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 95.78%, buildTime = 0.55s
#   n = 60, d = 20, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.25%, buildTime = 0.61s
#   n = 60, d = 22, s = 50, k = 30, maxDepth = 3:
#     accTest = 92.96%, accTrain = 96.96%, buildTime = 0.56s
#   n = 60, d = 24, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.49%, buildTime = 0.53s
#   n = 60, d = 26, s = 50, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 96.25%, buildTime = 0.60s
#   n = 60, d = 28, s = 50, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.25%, buildTime = 0.77s
#   n = 60, d = 30, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 97.19%, buildTime = 0.52s
#
#   Change s, keep other parameters
#   n = 60, d = 10, s = 10, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 95.78%, buildTime = 0.14s
#   n = 60, d = 10, s = 20, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.49%, buildTime = 0.26s
#   n = 60, d = 10, s = 30, k = 30, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.49%, buildTime = 0.40s
#   n = 60, d = 10, s = 40, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 95.78%, buildTime = 0.53s
#   n = 60, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 96.49%, buildTime = 0.71s
#   n = 60, d = 10, s = 60, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 94.85%, buildTime = 0.69s
#   n = 60, d = 10, s = 70, k = 30, maxDepth = 3:
#     accTest = 95.77%, accTrain = 97.42%, buildTime = 0.75s
#   n = 60, d = 10, s = 80, k = 30, maxDepth = 3:
#     accTest = 94.37%, accTrain = 95.78%, buildTime = 0.75s
#   n = 60, d = 10, s = 90, k = 30, maxDepth = 3:
#     accTest = 92.96%, accTrain = 97.66%, buildTime = 0.92s
#   n = 60, d = 10, s = 100, k = 30, maxDepth = 3:
#     accTest = 96.48%, accTrain = 97.19%, buildTime = 0.95s
#
#   Change k, keep other parameters
#   n = 60, d = 10, s = 50, k = 10, maxDepth = 3:
#     accTest = 94.37%, accTrain = 95.08%, buildTime = 0.18s
#   n = 60, d = 10, s = 50, k = 20, maxDepth = 3:
#     accTest = 95.07%, accTrain = 95.55%, buildTime = 0.37s
#   n = 60, d = 10, s = 50, k = 30, maxDepth = 3:
#     accTest = 93.66%, accTrain = 96.49%, buildTime = 0.50s
#   n = 60, d = 10, s = 50, k = 40, maxDepth = 3:
#     accTest = 94.37%, accTrain = 97.19%, buildTime = 0.58s
#   n = 60, d = 10, s = 50, k = 50, maxDepth = 3:
#     accTest = 95.77%, accTrain = 96.96%, buildTime = 0.97s
#   n = 60, d = 10, s = 50, k = 60, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.96%, buildTime = 1.33s
#   n = 60, d = 10, s = 50, k = 70, maxDepth = 3:
#     accTest = 94.37%, accTrain = 97.19%, buildTime = 1.45s
#   n = 60, d = 10, s = 50, k = 80, maxDepth = 3:
#     accTest = 95.07%, accTrain = 96.02%, buildTime = 1.54s
#   n = 60, d = 10, s = 50, k = 90, maxDepth = 3:
#     accTest = 95.07%, accTrain = 97.42%, buildTime = 1.65s
#   n = 60, d = 10, s = 50, k = 100, maxDepth = 3:
#     accTest = 94.37%, accTrain = 96.49%, buildTime = 2.06s
